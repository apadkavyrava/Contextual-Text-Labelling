# %%
import pandas as pd

# %%
goods = pd.read_csv(
    'Downloaded_datasets/Product_Taxonomy.txt')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 goods = pd.read_csv(
#       2     'Downloaded_datasets/Product_Taxonomy.txt',
#       3     header=None,
#       4     names=['product'],
#       5     sep='\n',
#       6
#       7 )
#
# ...
